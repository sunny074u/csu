# %%
#Install dependencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.96.0)
# Requirement already satisfied: python-dotenv in c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anthropic) (2.13.2)
# Requirement already satisfied: sniffio in c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.10)
# Requirement already satisfied: certifi in c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.2 in c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.2)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Load environment variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# create an api client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
# Making MY First Request
message = client.messages.create(
    model=model,
    max_tokens=300,
    messages=[
        {
            "role": "user",
            "content": "What is quantum computing? Answer in one sentence"
        }
    ]
)

# %%
# Extracting the Response
message.content[0].text
# Out:
# 'Quantum computing is a type of computation that uses quantum mechanical phenomena, such as superposition and entanglement, to process information in ways that can solve certain complex problems much faster than classical computers.'

# %%
# Multi-Turn conversations
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Define quantum computing in one sentence")

# Get Claude's response
answer = chat(messages)

# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "Write another sentence")

# Get the follow-up response with full context
final_answer = chat(messages)

# %%
# System Prompts
system_prompt = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""

client.messages.create(
    model=model,
    messages=messages,
    max_tokens=300,
    system=system_prompt
)
# Out:
# Message(id='msg_01QdwD5phfi8rsXWwaMMmTob', container=None, content=[TextBlock(citations=None, text='Unlike classical computers, which use bits that exist as either 0 or 1, quantum computers use **qubits** that can exist in multiple states simultaneously, allowing them to explore many possible solutions to a problem at the same time.', type='text')], model='claude-sonnet-4-6', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=95, output_tokens=52, server_tool_use=None, service_tier='standard'))

# %%
def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 300,
        "messages": messages,
    }
    
    if system:
        params["system"] = system
    
    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Without system prompt
answer = chat(messages)

# With system prompt
system = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""
answer = chat(messages, system=system)

# %%
def chat(messages, system=None, temperature=1.0):
    params = {
        "model": model,
        "max_tokens": 300,
        "messages": messages,
        "temperature": temperature
    }
    
    if system:
        params["system"] = system
    
    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Low temperature - more predictable
answer = chat(messages, temperature=0.0)

# %%
# High temperature - more creative  
answer = chat(messages, temperature=1.0)
